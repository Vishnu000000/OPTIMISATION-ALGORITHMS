# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

vishnu = 2 # 0 for multi, 1 for KW and soo on 6 for CE single objective



import time

def measure_time():
  """Measures the time taken to execute a code block.

  Returns:
    The time taken in milliseconds.
  """
  start_time = time.time()
  # Simulate some work being done
  for i in range(1000):
    pass
  end_time = time.time()
  return (end_time - start_time) * 1000  # Convert to milliseconds

execution_time = measure_time()
# Example usage


c1 = 336.5140 # Example constant values
c2 = 0.8789
c3 = 21.6165
c4 = 37.7269
c5 = 513.2847
c6 = 1197.9836

def switch_vishnu(vishnu):
    switch_dict = {
        0: (1/6,1/6,1/6,1/6,1/6,1/6),
        1: (1, 0, 0, 0, 0, 0),
        2: (0, 1, 0, 0, 0, 0),
        3: (0, 0, 1, 0, 0, 0),
        4: (0, 0, 0, 1, 0, 0),
        5: (0, 0, 0, 0, 1, 0),
        6: (0, 0, 0, 0, 0, 1)
    }

    return switch_dict.get(vishnu, (0, 0, 0, 0, 0, 0))


def switch_case(vishnu):
    switch_dict = {
        1: 'KW',
        2: 'PCV',
        3: 'SR',
        4: 'ED',
        5: 'LE',
        6: 'CE'
    }

    return switch_dict.get(vishnu, '')
# Example usage:

w1, w2, w3, w4, w5, w6 = switch_vishnu(vishnu)



# Define the objective function
def objective_function_multi(x):
    Toff, Ton, Sv, Ip = x
    KW = 81 + 6.66*Toff + 0.19*Ton + 0.665*Sv + 0.311*Ip - 0.0522*Toff*Toff + 0.0002*Ton*Ton - 0.00044*Sv*Sv - 0.000293*Ip*Ip - 0.0060*Toff*Ton - 0.00346*Toff*Sv - 0.00413*Toff*Ip- 0.00025*Ton*Sv + 0.00727*Ton*Ip - 0.00132*Sv*Ip
    PCV = 29.8 - 0.942*Toff + 0.327*Ton - 0.1848*Sv + 0.0769*Ip + 0.00733*Toff*Toff + 0.00018*Ton*Ton + 0.000505*Sv*Sv + 0.000006*Ip*Ip - 0.00321*Toff*Ton + 0.002936*Toff*Sv - 0.001016*Toff*Ip - 0.002419*Ton*Sv + 0.000788*Ton*Ip - 0.000348*Sv*Ip
    SR = -55.7 + 1.97*Toff + 1.011*Ton + 0.223*Sv + 0.123*Ip - 0.0195*Toff*Toff - 0.00414*Ton*Ton - 0.00223*Sv*Sv - 0.000372*Ip*Ip - 0.00998*Toff*Ton + 0.00155*Toff*Sv - 0.00050*Toff*Ip - 0.00574*Ton*Sv + 0.003548*Ton*Ip - 0.000498*Sv*Ip
    ED = 56.3 - 1.93*Toff + 0.908*Ton + 0.575*Sv + 0.230*Ip + 0.0161*Toff*Toff + 0.00243*Ton*Ton - 0.00221*Sv*Sv - 0.000953*Ip*Ip - 0.00252*Toff*Ton - 0.00391*Toff*Sv + 0.00025*Toff*Ip - 0.00929*Ton*Sv + 0.001208*Ton*Ip - 0.000628*Sv*Ip
    LE= 213 + 2.5*Toff + 1.17*Ton + 0.35*Sv + 1.882*Ip + 0.018*Toff*Toff + 0.1621*Ton*Ton - 0.0034*Sv*Sv + 0.00035*Ip*Ip - 0.0413*Toff*Ton + 0.0088*Toff*Sv - 0.0246*Toff*Ip - 0.0017*Ton*Sv - 0.02156*Ton*Ip - 0.00285*Sv*Ip
# Define the bounds for variables A, B, C, D
l_bounds = np.array([51, 5, 40, 70])
u_bounds = np.array([63, 25, 80, 150])

num_iterations = 1000

# Define the simple optimization algorithm
def simple_optimization(num_iterations):
    best_solution = None
    best_optimal = float('-inf')
    best_optimal_history = []  # To store the best optimal value at each iteration

    for iteration in range(num_iterations):
        # Generate a random solution within the bounds
        solution = np.random.uniform(l_bounds, u_bounds)

        # Evaluate the solution
        if vishnu == 0:
          optimal = objective_function_multi(solution)
        else:
          optimal = objective_function_single(solution)

        # Update the best solution if needed
        if optimal > best_optimal:
            best_solution = solution
            best_optimal = optimal

        # Store the best optimal value at each iteration
        best_optimal_history.append(best_optimal)

    return best_solution, best_optimal, best_optimal_history

# Run the simple optimization algorithm
best_solution, best_optimal, best_optimal_history = simple_optimization(num_iterations)


# Run the simple optimization algorithm 30 times
num_iterations = 1000
num_runs = 30

best_solution_sum = np.zeros(4)  # Accumulate solutions
best_optimal_sum = 0.0  # Accumulate optimal values
best_optimal_history_sum = np.zeros(num_iterations)  # Accumulate histories

for _ in range(num_runs):
    best_solution, best_optimal, best_optimal_history = simple_optimization(num_iterations)

    # Accumulate values
    best_solution_sum += best_solution
    best_optimal_sum += best_optimal
    best_optimal_history_sum += np.array(best_optimal_history)

# Calculate averages
average_best_solution = best_solution_sum / num_runs
average_best_optimal = best_optimal_sum / num_runs
average_best_optimal_history = best_optimal_history_sum / num_runs

# Print or use the averages as needed
print("Average Best Solution:", average_best_solution)
print("Average Best Optimal:", average_best_optimal)
print("Average Best Optimal History:", average_best_optimal_history)

# Plot the average best optimal value over iterations
plt.plot(range(1, num_iterations + 1), average_best_optimal_history)
plt.xlabel('Number of Iterations')
plt.ylabel('Average Best Optimal Value')
plt.title('Convergence Plot')
plt.grid(True)
plt.show()


if vishnu == 0:
    # Save the results to an Excel file
    results_df = pd.DataFrame({
         'Iteration': range(1, num_iterations + 1),
         'Best_Objective_Value': average_best_optimal_history})
    results_df.to_excel('SOPT_plot_multiobjective.xlsx', index=False)

    Toff = average_best_solution[0]
    Ton = average_best_solution[1]
    Sv = average_best_solution[2]
    Ip = average_best_solution[3]
    KW = 81 + 6.66*Toff + 0.19*Ton + 0.665*Sv + 0.311*Ip - 0.0522*Toff*Toff + 0.0002*Ton*Ton - 0.00044*Sv*Sv - 0.000293*Ip*Ip - 0.0060*Toff*Ton - 0.00346*Toff*Sv - 0.00413*Toff*Ip- 0.00025*Ton*Sv + 0.00727*Ton*Ip - 0.00132*Sv*Ip
    PCV = 29.8 - 0.942*Toff + 0.327*Ton - 0.1848*Sv + 0.0769*Ip + 0.00733*Toff*Toff + 0.00018*Ton*Ton + 0.000505*Sv*Sv + 0.000006*Ip*Ip - 0.00321*Toff*Ton + 0.002936*Toff*Sv - 0.001016*Toff*Ip - 0.002419*Ton*Sv + 0.000788*Ton*Ip - 0.000348*Sv*Ip
    SR = -55.7 + 1.97*Toff + 1.011*Ton + 0.223*Sv + 0.123*Ip - 0.0195*Toff*Toff - 0.00414*Ton*Ton - 0.00223*Sv*Sv - 0.000372*Ip*Ip - 0.00998*Toff*Ton + 0.00155*Toff*Sv - 0.00050*Toff*Ip - 0.00574*Ton*Sv + 0.003548*Ton*Ip - 0.000498*Sv*Ip
    ED = 56.3 - 1.93*Toff + 0.908*Ton + 0.575*Sv + 0.230*Ip + 0.0161*Toff*Toff + 0.00243*Ton*Ton - 0.00221*Sv*Sv - 0.000953*Ip*Ip - 0.00252*Toff*Ton - 0.00391*Toff*Sv + 0.00025*Toff*Ip - 0.00929*Ton*Sv + 0.001208*Ton*Ip - 0.000628*Sv*Ip
    LE= 213 + 2.5*Toff + 1.17*Ton + 0.35*Sv + 1.882*Ip + 0.018*Toff*Toff + 0.1621*Ton*Ton - 0.0034*Sv*Sv + 0.00035*Ip*Ip - 0.0413*Toff*Ton + 0.0088*Toff*Sv - 0.0246*Toff*Ip - 0.0017*Ton*Sv - 0.02156*Ton*Ip - 0.00285*Sv*Ip
    CE = 17673 - 578*Toff + 37.1*Ton - 20.4*Sv + 3.9*Ip + 4.83*Toff*Toff - 0.282*Ton*Ton - 0.032*Sv*Sv - 0.0235*Ip*Ip - 0.837*Toff*Ton + 0.476*Toff*Sv - 0.019*Toff*Ip - 0.194*Ton*Sv + 0.342*Ton*Ip - 0.0439*Sv*Ip
# Print the best solution and its optimal value
    print("Toff:", average_best_solution[0], end="; ")
    print("Ton:", average_best_solution[1], end="; ")
    print("Sv:", average_best_solution[2], end="; ")
    print("Ip:", average_best_solution[3])

    print("KW:", KW, end="; ")
    print("PCV:", PCV, end="; ")
    print("SR:", SR, end="; ")
    print("ED:", ED,end="; ")
    print("LE:", LE, end="; ")
    print("CE:", CE)

    print("Best Optimal(Z):", average_best_optimal)
    printed_values_df = pd.DataFrame({ 'Variable': ['Toff', 'Ton', 'Sv', 'Ip', 'KW', 'PCV', 'SR', 'ED', 'LE', 'CE', 'Best Optimal(Z)'],'Value': [average_best_solution[0], average_best_solution[1], average_best_solution[2], average_best_solution[3], KW, PCV, SR, ED, LE, CE, average_best_optimal]})
    printed_values_df.to_excel('/content/SOPT_multiobjective_values.xlsx', index=False)
else:
    switch_var = switch_case(vishnu)

    results_df = pd.DataFrame({
         'Iteration': range(1, num_iterations + 1),
         'Best_Objective_Value': average_best_optimal_history})
    results_df.to_excel('SOPT_plot_' + switch_var +'.xlsx', index=False)

    # Print values for single-objective optimization
    Toff = average_best_solution[0]
    Ton = average_best_solution[1]
    Sv = average_best_solution[2]
    Ip = average_best_solution[3]
    print("Toff:", average_best_solution[0], end="; ")
    print("Ton:", average_best_solution[1], end="; ")
    print("Sv:", average_best_solution[2], end="; ")
    print("Ip:", average_best_solution[3])
    print(switch_var+':', average_best_optimal)
    printed_values_df = pd.DataFrame({
    'Variable': ['Toff', 'Ton', 'Sv', 'Ip', switch_var ],
    'Value': [average_best_solution[0], average_best_solution[1], average_best_solution[2], average_best_solution[3], average_best_optimal]})
    printed_values_df.to_excel('SOPT_singleobjective_'+switch_var+ '.xlsx', index=False)





